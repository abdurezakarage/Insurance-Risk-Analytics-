# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.services.insurance_analysis import InsuranceAnalysis

# %%
# Load and preprocess the data
df = pd.read_csv("../Data/raw/MachineLearningRating_v3.txt", sep='|')
# Out:
# C:\Users\op\AppData\Local\Temp\ipykernel_100\2635911300.py:2: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Data/raw/MachineLearningRating_v3.txt", sep='|')

# %%
 # Initialize analysis
 analysis = InsuranceAnalysis(df)

# %%
analysis.analyze_data_types()
# Out:
# === Data Types Analysis ===
#                          Data Type  Non-Null Count  Null Count  \
# UnderwrittenCoverID          int64         1000098           0
# PolicyID                     int64         1000098           0
# TransactionMonth            object         1000098           0
# IsVATRegistered               bool         1000098           0
# Citizenship                 object         1000098           0
# LegalType                   object         1000098           0
# Title                       object         1000098           0
# Language                    object         1000098           0
# Bank                        object          854137      145961
# AccountType                 object          959866       40232
# MaritalStatus               object          991839        8259
# Gender                      object          990562        9536
# Country                     object         1000098           0
# ...

# %%
df_clean= analysis.outliers_boxplot()
# Out:
# Outlier Removal for TotalPremium:
# Lower bound: -32.89, Upper bound: 54.82
# Number of outliers removed: 209042
# Percentage of data removed: 20.90%
# Outlier Removal for TotalClaims:
# Lower bound: 0.00, Upper bound: 0.00
# Number of outliers removed: 2793
# Percentage of data removed: 0.28%
#
# Total rows removed: 210005
# Remaining rows: 790093

# %%
Cleaned_analysis= InsuranceAnalysis(df_clean)

# %%
Cleaned_analysis.analyze_portfolio()
# Out:
# Total Premium sum: 3,399,928.81
# Total Claims sum: 0.00
# Number of records: 790093
# Records with zero or negative premium: 381641
# Records with negative claims: 0
#
# Overall Portfolio Loss Ratio:
# Loss Ratio: 0.0000

# %%
Cleaned_analysis.analyze_categorical_features()
# Out:
# === Categorical Features Analysis ===
#
# TransactionMonth:
# Unique values: 23
# Most common values:
# TransactionMonth
# 2015-08-01 00:00:00    83406
# 2015-07-01 00:00:00    80925
# 2015-06-01 00:00:00    80186
# 2015-05-01 00:00:00    78384
# 2015-04-01 00:00:00    74918
# Name: count, dtype: int64
# Least common values:
# TransactionMonth
# 2014-02-01 00:00:00    1871
# 2014-01-01 00:00:00    1653
# 2013-12-01 00:00:00    1357
# 2013-11-01 00:00:00    1106
# 2013-10-01 00:00:00      42
# Name: count, dtype: int64
#
# Citizenship:
# Unique values: 4
# Most common values:
# Citizenship
#       704440
# ZA     84756
# ZW       708
# AF       189
# Name: count, dtype: int64
# Least common values:
# Citizenship
#       704440
# ZA     84756
# ZW       708
# AF       189
# Name: count, dtype: int64
#
# LegalType:
# Unique values: 6
# Most common values:
# LegalType
# Individual           719282
# Private company       67465
# Close Corporation      2061
# Public company          899
# ...

# %%
Cleaned_analysis.analyze_temporal_trends()

# %%
Cleaned_analysis.analyze_geographic_trends()
# Out:
# e:\AI\Week-3\Week-3-task\Insurance-Risk-Analytics-\src\services\insurance_analysis.py:412: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Geographic Trends Summary:
#
# 1. Premium Statistics by Province:
#                    mean        std        min        max
# Province
# Eastern Cape   5.748193  10.892465 -27.777778  54.706216
# Free State     6.283057  11.459297   0.000000  50.751880
# Gauteng        3.757513   7.538007 -31.267685  54.678363
# KwaZulu-Natal  5.531176  10.293761 -30.560272  54.725263
# Limpopo        5.484590  10.341267   0.000000  54.678363
# Mpumalanga     3.441525   7.203609   0.000000  54.717444
# North West     4.306722   9.275918   0.000000  54.678363
# Northern Cape  4.311659   9.859106   0.000000  52.631579
# Western Cape   4.076103   8.628459 -13.458303  54.774503
#
# 3. Most Common Cover Types by Province:
# Province
# ...

# %%
Cleaned_analysis.analyze_numerical_features()
# Out:
# === Numerical Features Analysis ===
#                            Count          Mean           Std           Min  \
# UnderwrittenCoverID       790093  1.019925e+05  6.300553e+04  1.000000e+00
# PolicyID                  790093  7.728512e+03  5.252633e+03  1.400000e+01
# PostalCode                790093  3.067071e+03  2.674409e+03  1.000000e+00
# mmcode                    789620  5.478316e+07  1.375790e+07  4.041200e+06
# RegistrationYear          790093  2.010191e+03  3.268732e+00  1.987000e+03
# Cylinders                 789620  4.047199e+00  2.955091e-01  0.000000e+00
# cubiccapacity             789620  2.455207e+03  4.585107e+02  0.000000e+00
# kilowatts                 789620  9.696607e+01  1.953781e+01  0.000000e+00
# NumberOfDoors             789620  4.023781e+00  4.760994e-01  0.000000e+00
# CustomValueEstimate       168019  2.223259e+05  5.215316e+05  2.000000e+04
# NumberOfVehiclesInFleet        0           NaN           NaN           NaN
# ...

# %%
Cleaned_analysis.compare_regional_metrics()
# Out:
# e:\AI\Week-3\Week-3-task\Insurance-Risk-Analytics-\src\services\insurance_analysis.py:465: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x=group_by, y=metric, data=self.df, ax=ax2,
# Detailed Statistics for TotalPremium by Province:
#                 count      mean        std        min        max   Q1  \
# Province
# Eastern Cape    23982  5.748193  10.892465 -27.777778  54.706216  0.0
# Free State       6092  6.283057  11.459297   0.000000  50.751880  0.0
# Gauteng        305661  3.757513   7.538007 -31.267685  54.678363  0.0
# KwaZulu-Natal  135018  5.531176  10.293761 -30.560272  54.725263  0.0
# Limpopo         18693  5.484590  10.341267   0.000000  54.678363  0.0
# Mpumalanga      41998  3.441525   7.203609   0.000000  54.717444  0.0
# North West     112499  4.306722   9.275918   0.000000  54.678363  0.0
# Northern Cape    5013  4.311659   9.859106   0.000000  52.631579  0.0
# ...
